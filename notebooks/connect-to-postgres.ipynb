# %%
import psycopg2

# %%
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="cuad",
    user="cuad_user",
    password="cuad_password"
)

cur = conn.cursor()
cur.execute("SELECT 1;")
print(cur.fetchone())

cur.close()
conn.close()
# Out:
# (1,)

# %%
from sqlmodel import SQLModel, create_engine, Session, text

DATABASE_URL = "postgresql://cuad_user:cuad_password@localhost:5432/cuad"

engine = create_engine(DATABASE_URL, echo=True)

# Create tables (optional)
SQLModel.metadata.create_all(engine)

# Test connection
with Session(engine) as session:
    result = session.exec(text("SELECT 1;"))
    print(result.all())
# Out:
# 2025-11-30 21:09:38,528 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-11-30 21:09:38,528 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-30 21:09:38,530 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-11-30 21:09:38,531 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-30 21:09:38,533 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-11-30 21:09:38,533 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-30 21:09:38,534 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-30 21:09:38,535 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-30 21:09:38,536 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-30 21:09:38,536 INFO sqlalchemy.engine.Engine SELECT 1;
# 2025-11-30 21:09:38,537 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# [(1,)]
# 2025-11-30 21:09:38,538 INFO sqlalchemy.engine.Engine ROLLBACK
